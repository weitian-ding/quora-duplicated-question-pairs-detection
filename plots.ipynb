# %%
import xgboost as xgb
import matplotlib.pyplot as plt

# %%
bst = xgb.Booster({'nthread':2})
bst.load_model("models/bst-2017-04-15-185503.model")

# %%
xgb.plot_importance(bst); plt.show()

# %%
xgb.plot_tree(bst, num_trees=0); plt.show()
